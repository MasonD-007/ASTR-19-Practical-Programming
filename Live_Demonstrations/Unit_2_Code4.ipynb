# %% [markdown]
# For the demonstration, you should create a jupyter notebook from scratch does the
# following things:
#
# First cell: Use Markdown to title the notebook ”Unit 2 Code Demo”
#
# Second cell: Import the matplotlib.pyplot and numpy modules.
#
# Third cell: Use numpy linspace to create an array x with 100 elements between 0 and 2 . and numpy to create an array y equal to sine of 5x
#
# Fourth cell: use matplotlib.pyplot to x vs y. Limit the y-axis to [-1.1,1.1].
#
# Fifth cell: label the x and y axes.
#
# Sixth cell: save the figure as “demo.png” with a background color other than white.

# %% [markdown]
# Unit 2 Code Demo

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2,100)
y = np.sin(5*x)

# %%
fig = plt.figure()
plt.plot(x,y)
plt.ylim(-1.1,1.1)
# Out:
# (-1.1, 1.1)

# %%
fig.gca().set_xlabel("X - Num")
fig.gca().set_ylabel("Y - Sin of 5 X")
fig

# %%
fig.savefig("demo.png", facecolor="Pink")
